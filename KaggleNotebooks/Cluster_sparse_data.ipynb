# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import sparse
from sklearn.preprocessing import MaxAbsScaler
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

# %%
X_sparse = sparse.load_npz('train.npz')
#X_scaled = MaxAbsScaler().fit_transform(X_sparse)
X_std = X_sparse.toarray()
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_std)

# %%
def tf(labels,fname="submission.csv"):
    submission = pd.DataFrame({
        'ID': range(len(labels)),
        'TARGET': labels
    })
    submission.to_csv(fname, index=False)

# %%
km = KMeans(
    n_clusters=9,
    random_state=42
)
labels = km.fit_predict(X_scaled)
tf(labels)

# %%
X_std.shape
# Out:
# (21000, 3049)

# %%
inertia = []
seed_list = [1,10,100]

for s in seed_list:
    k = 7
    print(f"start seed = {s}, k = {k}") 
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    tf(kmeans.fit_predict(X_scaled),f"s{s}k{k}.csv")
for s in seed_list:
    k = 8
    print(f"start seed = {s}, k = {k}") 
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    tf(kmeans.fit_predict(X_scaled),f"s{s}k{k}.csv")
# Out:
# start seed = 1, k = 7
# start seed = 10, k = 7
# start seed = 100, k = 7
# start seed = 1, k = 8
# start seed = 10, k = 8
# start seed = 100, k = 8

# %%
transformer = Normalizer().fit(X_scaled)
normalized_data = transformer.transform(X_scaled)
